# %%
# Importamos librerias que se usarán

import pandas as pd
import warnings
import re # Regular expression operations. Provides regular expressssion matching operations

warnings.filterwarnings("ignore")

# %%
# anchos_de_columna = [9, 16, 16, 350]

# column_names = [
#     "cluster",
#     "cantidad_de_palabras_clave",
#     "porcentaje_de_palabras_clave",
#     "principales_palabras_clave",
# ]

# archivo_clusters = "clusters_report.txt"

# %%
# Leer el archivo con el formato de ancho fijo
cluster_df = pd.read_fwf(
    # read_fwf() reads fixed width files.
    "clusters_report.txt",
    widths=[9, 16, 16, 350],
    header=None,
    names=[
    "cluster",
    "cantidad_de_palabras_clave",
    "porcentaje_de_palabras_clave",
    "principales_palabras_clave",
],
)

cluster_df
# Out:
#       cluster cantidad_de_palabras_clave porcentaje_de_palabras_clave  \
# 0     Cluster                Cantidad de                Porcentaje de
# 1         NaN             palabras clave               palabras clave
# 2   ---------           ----------------             ----------------
# 3           1                        105                       15,9 %
# 4         NaN                        NaN                          NaN
# 5         NaN                        NaN                          NaN
# 6         NaN                        NaN                          NaN
# 7           2                        102                       15,4 %
# 8         NaN                        NaN                          NaN
# 9         NaN                        NaN                          NaN
# 10        NaN                        NaN                          NaN
# 11        NaN                        NaN                          NaN
# 12          3                         89                       13,4 %
# 13        NaN                        NaN                          NaN
# 14        NaN                        NaN                          NaN
# 15          4                         60                        9,1 %
# 16        NaN                        NaN                          NaN
# 17        NaN                        NaN                          NaN
# 18        NaN                        NaN                          NaN
# 19          5                         52                        7,9 %
# 20        NaN                        NaN                          NaN
# 21        NaN                        NaN                          NaN
# 22        NaN                        NaN                          NaN
# 23          6                         51                        7,7 %
# 24        NaN                        NaN                          NaN
# 25        NaN                        NaN                          NaN
# 26        NaN                        NaN                          NaN
# 27          7                         42                        6,3 %
# 28        NaN                        NaN                          NaN
# 29        NaN                        NaN                          NaN
# 30        NaN                        NaN                          NaN
# 31          8                         38                        5,7 %
# 32        NaN                        NaN                          NaN
# 33        NaN                        NaN                          NaN
# 34        NaN                        NaN                          NaN
# 35          9                         35                        5,3 %
# 36        NaN                        NaN                          NaN
# 37        NaN                        NaN                          NaN
# 38        NaN                        NaN                          NaN
# 39         10                         27                        4,1 %
# 40        NaN                        NaN                          NaN
# 41        NaN                        NaN                          NaN
# 42        NaN                        NaN                          NaN
# 43         11                         22                        3,3 %
# 44        NaN                        NaN                          NaN
# 45         12                         22                        3,3 %
# 46        NaN                        NaN                          NaN
# 47        NaN                        NaN                          NaN
# 48        NaN                        NaN                          NaN
# 49        NaN                        NaN                          NaN
# 50         13                         17                        2,6 %
# 51        NaN                        NaN                          NaN
# 52        NaN                        NaN                          NaN
# 53        NaN                        NaN                          NaN
#
#                            principales_palabras_clave
# 0                          Principales palabras clave
# 1                                                 NaN
# 2   ----------------------------------------------...
# 3   maximum power point tracking, fuzzy-logic base...
# 4   photo-voltaic  system,  differential   evoluti...
# 5   algorithm, double-fed induction generator (dfi...
# 6   photo voltaic array, firefly algorithm, partia...
# 7   support vector machine,  long  short-term  mem...
# 8   network,  convolution  neural  network,  speed...
# 9   consumption,   wind   power   forecasting,   e...
# 10  recurrent-neural-network (rnn), radial basis f...
# 11                                              farm.
# 12  smart grid, wind power, reinforcement learning...
# 13  efficiency, solar energy, deep reinforcement l...
# 14  internet of things, energy harvester, q-learning.
# 15  wind   turbine,   fault    diagnosis,    biodi...
# 16  response-surface methodology, condition monito...
# 17  consumption forecast,  anomalies  detection,  ...
# 18          supervisory control and data acquisition.
# 19  electric vehicle, lithium-ion batteries, state...
# 20  hybrid-electric vehicle, energy  management  s...
# 21  system, remaining useful life, battery managem...
# 22                             hybrid energy storage.
# 23  particle  swarm  optimization,  distribute  ge...
# 24  artificial  bee   colonies,   energy   storage...
# 25  gravitational search algorithm, distributed  s...
# 26  optimization  (mopso),  optimal  power-flow  (...
# 27  multi-objective   optimization,   energy   sto...
# 28  non-dominated  sorting  genetic  algorithm,   ...
# 29  renewable energy source, plug-in electric vehi...
# 30  multi-objective genetic algorithm, unit-commit...
# 31  genetic algorithm, demand-side  management,  e...
# 32  system (hes), wind turbine blade, data-driven ...
# 33  solar forecasting, geographic information syst...
# 34                                      cogeneration.
# 35  anfis,   global   solar   irradiance,  solar  ...
# 36  programing,   islanding   detection,   expert ...
# 37  evolutionary computation,  wavelet-based  neur...
# 38                       errors, virtual power plant.
# 39  micro grid,  multi-agent  systems,  distribute...
# 40  energy storage system, dc micro grid, pitch-co...
# 41  ac/dc microgrid, voltage regulation, supercond...
# 42                               distributed-control.
# 43  hydrogen,  biochar,  biomass,  biogas,  microb...
# 44  biofuel, ethanol, engine performance, pyrolysi...
# 45  state of charge (soc) estimation,  radial  bas...
# 46  forecasting,  computational  fluid  dynamics, ...
# 47  network,  monte-carlo   simulation,   multiple...
# 48  generation,   nonlinear   auto-regressive   ex...
# 49  networks, surrogate model, extreme gradient bo...
# 50  pem   fuel   cell,   solid-oxide  fuel  cell, ...
# 51  optimisation, particles-size  distributions,  ...
# 52  battery    management,    hydrogen     product...
# 53                             system-identification.

# %%
# Eliminar las primeras filas innecesarias
cluster_df = cluster_df.drop([0, 1, 2])

# Resetear los índices del DataFrame
cluster_df = cluster_df.reset_index(drop=True)

cluster_df
# Out:
#    cluster cantidad_de_palabras_clave porcentaje_de_palabras_clave  \
# 0        1                        105                       15,9 %
# 1      NaN                        NaN                          NaN
# 2      NaN                        NaN                          NaN
# 3      NaN                        NaN                          NaN
# 4        2                        102                       15,4 %
# 5      NaN                        NaN                          NaN
# 6      NaN                        NaN                          NaN
# 7      NaN                        NaN                          NaN
# 8      NaN                        NaN                          NaN
# 9        3                         89                       13,4 %
# 10     NaN                        NaN                          NaN
# 11     NaN                        NaN                          NaN
# 12       4                         60                        9,1 %
# 13     NaN                        NaN                          NaN
# 14     NaN                        NaN                          NaN
# 15     NaN                        NaN                          NaN
# 16       5                         52                        7,9 %
# 17     NaN                        NaN                          NaN
# 18     NaN                        NaN                          NaN
# 19     NaN                        NaN                          NaN
# 20       6                         51                        7,7 %
# 21     NaN                        NaN                          NaN
# 22     NaN                        NaN                          NaN
# 23     NaN                        NaN                          NaN
# 24       7                         42                        6,3 %
# 25     NaN                        NaN                          NaN
# 26     NaN                        NaN                          NaN
# 27     NaN                        NaN                          NaN
# 28       8                         38                        5,7 %
# 29     NaN                        NaN                          NaN
# 30     NaN                        NaN                          NaN
# 31     NaN                        NaN                          NaN
# 32       9                         35                        5,3 %
# 33     NaN                        NaN                          NaN
# 34     NaN                        NaN                          NaN
# 35     NaN                        NaN                          NaN
# 36      10                         27                        4,1 %
# 37     NaN                        NaN                          NaN
# 38     NaN                        NaN                          NaN
# 39     NaN                        NaN                          NaN
# 40      11                         22                        3,3 %
# 41     NaN                        NaN                          NaN
# 42      12                         22                        3,3 %
# 43     NaN                        NaN                          NaN
# 44     NaN                        NaN                          NaN
# 45     NaN                        NaN                          NaN
# 46     NaN                        NaN                          NaN
# 47      13                         17                        2,6 %
# 48     NaN                        NaN                          NaN
# 49     NaN                        NaN                          NaN
# 50     NaN                        NaN                          NaN
#
#                            principales_palabras_clave
# 0   maximum power point tracking, fuzzy-logic base...
# 1   photo-voltaic  system,  differential   evoluti...
# 2   algorithm, double-fed induction generator (dfi...
# 3   photo voltaic array, firefly algorithm, partia...
# 4   support vector machine,  long  short-term  mem...
# 5   network,  convolution  neural  network,  speed...
# 6   consumption,   wind   power   forecasting,   e...
# 7   recurrent-neural-network (rnn), radial basis f...
# 8                                               farm.
# 9   smart grid, wind power, reinforcement learning...
# 10  efficiency, solar energy, deep reinforcement l...
# 11  internet of things, energy harvester, q-learning.
# 12  wind   turbine,   fault    diagnosis,    biodi...
# 13  response-surface methodology, condition monito...
# 14  consumption forecast,  anomalies  detection,  ...
# 15          supervisory control and data acquisition.
# 16  electric vehicle, lithium-ion batteries, state...
# 17  hybrid-electric vehicle, energy  management  s...
# 18  system, remaining useful life, battery managem...
# 19                             hybrid energy storage.
# 20  particle  swarm  optimization,  distribute  ge...
# 21  artificial  bee   colonies,   energy   storage...
# 22  gravitational search algorithm, distributed  s...
# 23  optimization  (mopso),  optimal  power-flow  (...
# 24  multi-objective   optimization,   energy   sto...
# 25  non-dominated  sorting  genetic  algorithm,   ...
# 26  renewable energy source, plug-in electric vehi...
# 27  multi-objective genetic algorithm, unit-commit...
# 28  genetic algorithm, demand-side  management,  e...
# 29  system (hes), wind turbine blade, data-driven ...
# 30  solar forecasting, geographic information syst...
# 31                                      cogeneration.
# 32  anfis,   global   solar   irradiance,  solar  ...
# 33  programing,   islanding   detection,   expert ...
# 34  evolutionary computation,  wavelet-based  neur...
# 35                       errors, virtual power plant.
# 36  micro grid,  multi-agent  systems,  distribute...
# 37  energy storage system, dc micro grid, pitch-co...
# 38  ac/dc microgrid, voltage regulation, supercond...
# 39                               distributed-control.
# 40  hydrogen,  biochar,  biomass,  biogas,  microb...
# 41  biofuel, ethanol, engine performance, pyrolysi...
# 42  state of charge (soc) estimation,  radial  bas...
# 43  forecasting,  computational  fluid  dynamics, ...
# 44  network,  monte-carlo   simulation,   multiple...
# 45  generation,   nonlinear   auto-regressive   ex...
# 46  networks, surrogate model, extreme gradient bo...
# 47  pem   fuel   cell,   solid-oxide  fuel  cell, ...
# 48  optimisation, particles-size  distributions,  ...
# 49  battery    management,    hydrogen     product...
# 50                             system-identification.

# %%
# Convertir 'principales_palabras_clave' a tipo str
cluster_df["principales_palabras_clave"] = cluster_df[
    "principales_palabras_clave"
].astype(str)

cluster_df
# Out:
#    cluster cantidad_de_palabras_clave porcentaje_de_palabras_clave  \
# 0        1                        105                       15,9 %
# 1      NaN                        NaN                          NaN
# 2      NaN                        NaN                          NaN
# 3      NaN                        NaN                          NaN
# 4        2                        102                       15,4 %
# 5      NaN                        NaN                          NaN
# 6      NaN                        NaN                          NaN
# 7      NaN                        NaN                          NaN
# 8      NaN                        NaN                          NaN
# 9        3                         89                       13,4 %
# 10     NaN                        NaN                          NaN
# 11     NaN                        NaN                          NaN
# 12       4                         60                        9,1 %
# 13     NaN                        NaN                          NaN
# 14     NaN                        NaN                          NaN
# 15     NaN                        NaN                          NaN
# 16       5                         52                        7,9 %
# 17     NaN                        NaN                          NaN
# 18     NaN                        NaN                          NaN
# 19     NaN                        NaN                          NaN
# 20       6                         51                        7,7 %
# 21     NaN                        NaN                          NaN
# 22     NaN                        NaN                          NaN
# 23     NaN                        NaN                          NaN
# 24       7                         42                        6,3 %
# 25     NaN                        NaN                          NaN
# 26     NaN                        NaN                          NaN
# 27     NaN                        NaN                          NaN
# 28       8                         38                        5,7 %
# 29     NaN                        NaN                          NaN
# 30     NaN                        NaN                          NaN
# 31     NaN                        NaN                          NaN
# 32       9                         35                        5,3 %
# 33     NaN                        NaN                          NaN
# 34     NaN                        NaN                          NaN
# 35     NaN                        NaN                          NaN
# 36      10                         27                        4,1 %
# 37     NaN                        NaN                          NaN
# 38     NaN                        NaN                          NaN
# 39     NaN                        NaN                          NaN
# 40      11                         22                        3,3 %
# 41     NaN                        NaN                          NaN
# 42      12                         22                        3,3 %
# 43     NaN                        NaN                          NaN
# 44     NaN                        NaN                          NaN
# 45     NaN                        NaN                          NaN
# 46     NaN                        NaN                          NaN
# 47      13                         17                        2,6 %
# 48     NaN                        NaN                          NaN
# 49     NaN                        NaN                          NaN
# 50     NaN                        NaN                          NaN
#
#                            principales_palabras_clave
# 0   maximum power point tracking, fuzzy-logic base...
# 1   photo-voltaic  system,  differential   evoluti...
# 2   algorithm, double-fed induction generator (dfi...
# 3   photo voltaic array, firefly algorithm, partia...
# 4   support vector machine,  long  short-term  mem...
# 5   network,  convolution  neural  network,  speed...
# 6   consumption,   wind   power   forecasting,   e...
# 7   recurrent-neural-network (rnn), radial basis f...
# 8                                               farm.
# 9   smart grid, wind power, reinforcement learning...
# 10  efficiency, solar energy, deep reinforcement l...
# 11  internet of things, energy harvester, q-learning.
# 12  wind   turbine,   fault    diagnosis,    biodi...
# 13  response-surface methodology, condition monito...
# 14  consumption forecast,  anomalies  detection,  ...
# 15          supervisory control and data acquisition.
# 16  electric vehicle, lithium-ion batteries, state...
# 17  hybrid-electric vehicle, energy  management  s...
# 18  system, remaining useful life, battery managem...
# 19                             hybrid energy storage.
# 20  particle  swarm  optimization,  distribute  ge...
# 21  artificial  bee   colonies,   energy   storage...
# 22  gravitational search algorithm, distributed  s...
# 23  optimization  (mopso),  optimal  power-flow  (...
# 24  multi-objective   optimization,   energy   sto...
# 25  non-dominated  sorting  genetic  algorithm,   ...
# 26  renewable energy source, plug-in electric vehi...
# 27  multi-objective genetic algorithm, unit-commit...
# 28  genetic algorithm, demand-side  management,  e...
# 29  system (hes), wind turbine blade, data-driven ...
# 30  solar forecasting, geographic information syst...
# 31                                      cogeneration.
# 32  anfis,   global   solar   irradiance,  solar  ...
# 33  programing,   islanding   detection,   expert ...
# 34  evolutionary computation,  wavelet-based  neur...
# 35                       errors, virtual power plant.
# 36  micro grid,  multi-agent  systems,  distribute...
# 37  energy storage system, dc micro grid, pitch-co...
# 38  ac/dc microgrid, voltage regulation, supercond...
# 39                               distributed-control.
# 40  hydrogen,  biochar,  biomass,  biogas,  microb...
# 41  biofuel, ethanol, engine performance, pyrolysi...
# 42  state of charge (soc) estimation,  radial  bas...
# 43  forecasting,  computational  fluid  dynamics, ...
# 44  network,  monte-carlo   simulation,   multiple...
# 45  generation,   nonlinear   auto-regressive   ex...
# 46  networks, surrogate model, extreme gradient bo...
# 47  pem   fuel   cell,   solid-oxide  fuel  cell, ...
# 48  optimisation, particles-size  distributions,  ...
# 49  battery    management,    hydrogen     product...
# 50                             system-identification.

# %%
# Reemplazar '%' con '', y ',' con '.' en 'porcentaje_de_palabras_clave' y convertirlo a tipo float
cluster_df["porcentaje_de_palabras_clave"] = (
    cluster_df["porcentaje_de_palabras_clave"]
    .str.replace("%", "")
    .str.replace(",", ".")
    .astype(float)
)

cluster_df
# Out:
#    cluster cantidad_de_palabras_clave  porcentaje_de_palabras_clave  \
# 0        1                        105                          15.9
# 1      NaN                        NaN                           NaN
# 2      NaN                        NaN                           NaN
# 3      NaN                        NaN                           NaN
# 4        2                        102                          15.4
# 5      NaN                        NaN                           NaN
# 6      NaN                        NaN                           NaN
# 7      NaN                        NaN                           NaN
# 8      NaN                        NaN                           NaN
# 9        3                         89                          13.4
# 10     NaN                        NaN                           NaN
# 11     NaN                        NaN                           NaN
# 12       4                         60                           9.1
# 13     NaN                        NaN                           NaN
# 14     NaN                        NaN                           NaN
# 15     NaN                        NaN                           NaN
# 16       5                         52                           7.9
# 17     NaN                        NaN                           NaN
# 18     NaN                        NaN                           NaN
# 19     NaN                        NaN                           NaN
# 20       6                         51                           7.7
# 21     NaN                        NaN                           NaN
# 22     NaN                        NaN                           NaN
# 23     NaN                        NaN                           NaN
# 24       7                         42                           6.3
# 25     NaN                        NaN                           NaN
# 26     NaN                        NaN                           NaN
# 27     NaN                        NaN                           NaN
# 28       8                         38                           5.7
# 29     NaN                        NaN                           NaN
# 30     NaN                        NaN                           NaN
# 31     NaN                        NaN                           NaN
# 32       9                         35                           5.3
# 33     NaN                        NaN                           NaN
# 34     NaN                        NaN                           NaN
# 35     NaN                        NaN                           NaN
# 36      10                         27                           4.1
# 37     NaN                        NaN                           NaN
# 38     NaN                        NaN                           NaN
# 39     NaN                        NaN                           NaN
# 40      11                         22                           3.3
# 41     NaN                        NaN                           NaN
# 42      12                         22                           3.3
# 43     NaN                        NaN                           NaN
# 44     NaN                        NaN                           NaN
# 45     NaN                        NaN                           NaN
# 46     NaN                        NaN                           NaN
# 47      13                         17                           2.6
# 48     NaN                        NaN                           NaN
# 49     NaN                        NaN                           NaN
# 50     NaN                        NaN                           NaN
#
#                            principales_palabras_clave
# 0   maximum power point tracking, fuzzy-logic base...
# 1   photo-voltaic  system,  differential   evoluti...
# 2   algorithm, double-fed induction generator (dfi...
# 3   photo voltaic array, firefly algorithm, partia...
# 4   support vector machine,  long  short-term  mem...
# 5   network,  convolution  neural  network,  speed...
# 6   consumption,   wind   power   forecasting,   e...
# 7   recurrent-neural-network (rnn), radial basis f...
# 8                                               farm.
# 9   smart grid, wind power, reinforcement learning...
# 10  efficiency, solar energy, deep reinforcement l...
# 11  internet of things, energy harvester, q-learning.
# 12  wind   turbine,   fault    diagnosis,    biodi...
# 13  response-surface methodology, condition monito...
# 14  consumption forecast,  anomalies  detection,  ...
# 15          supervisory control and data acquisition.
# 16  electric vehicle, lithium-ion batteries, state...
# 17  hybrid-electric vehicle, energy  management  s...
# 18  system, remaining useful life, battery managem...
# 19                             hybrid energy storage.
# 20  particle  swarm  optimization,  distribute  ge...
# 21  artificial  bee   colonies,   energy   storage...
# 22  gravitational search algorithm, distributed  s...
# 23  optimization  (mopso),  optimal  power-flow  (...
# 24  multi-objective   optimization,   energy   sto...
# 25  non-dominated  sorting  genetic  algorithm,   ...
# 26  renewable energy source, plug-in electric vehi...
# 27  multi-objective genetic algorithm, unit-commit...
# 28  genetic algorithm, demand-side  management,  e...
# 29  system (hes), wind turbine blade, data-driven ...
# 30  solar forecasting, geographic information syst...
# 31                                      cogeneration.
# 32  anfis,   global   solar   irradiance,  solar  ...
# 33  programing,   islanding   detection,   expert ...
# 34  evolutionary computation,  wavelet-based  neur...
# 35                       errors, virtual power plant.
# 36  micro grid,  multi-agent  systems,  distribute...
# 37  energy storage system, dc micro grid, pitch-co...
# 38  ac/dc microgrid, voltage regulation, supercond...
# 39                               distributed-control.
# 40  hydrogen,  biochar,  biomass,  biogas,  microb...
# 41  biofuel, ethanol, engine performance, pyrolysi...
# 42  state of charge (soc) estimation,  radial  bas...
# 43  forecasting,  computational  fluid  dynamics, ...
# 44  network,  monte-carlo   simulation,   multiple...
# 45  generation,   nonlinear   auto-regressive   ex...
# 46  networks, surrogate model, extreme gradient bo...
# 47  pem   fuel   cell,   solid-oxide  fuel  cell, ...
# 48  optimisation, particles-size  distributions,  ...
# 49  battery    management,    hydrogen     product...
# 50                             system-identification.

# %%
# Llenar los valores vacíos en 'cluster', 'cantidad_de_palabras_clave' y 'porcentaje_de_palabras_clave'
cluster_df["cluster"] = cluster_df["cluster"].fillna(method="pad")
cluster_df["cantidad_de_palabras_clave"] = cluster_df[
    "cantidad_de_palabras_clave"
].fillna(method="pad")
cluster_df["porcentaje_de_palabras_clave"] = cluster_df[
    "porcentaje_de_palabras_clave"
].fillna(method="pad")
# estamos utilizando el método "pad" para rellenar los valores faltantes hacia adelante. 
# Esto significa que cualquier valor NaN se reemplazará por el último valor válido en la misma columna antes de él.
cluster_df
# Out:
#    cluster cantidad_de_palabras_clave  porcentaje_de_palabras_clave  \
# 0        1                        105                          15.9
# 1        1                        105                          15.9
# 2        1                        105                          15.9
# 3        1                        105                          15.9
# 4        2                        102                          15.4
# 5        2                        102                          15.4
# 6        2                        102                          15.4
# 7        2                        102                          15.4
# 8        2                        102                          15.4
# 9        3                         89                          13.4
# 10       3                         89                          13.4
# 11       3                         89                          13.4
# 12       4                         60                           9.1
# 13       4                         60                           9.1
# 14       4                         60                           9.1
# 15       4                         60                           9.1
# 16       5                         52                           7.9
# 17       5                         52                           7.9
# 18       5                         52                           7.9
# 19       5                         52                           7.9
# 20       6                         51                           7.7
# 21       6                         51                           7.7
# 22       6                         51                           7.7
# 23       6                         51                           7.7
# 24       7                         42                           6.3
# 25       7                         42                           6.3
# 26       7                         42                           6.3
# 27       7                         42                           6.3
# 28       8                         38                           5.7
# 29       8                         38                           5.7
# 30       8                         38                           5.7
# 31       8                         38                           5.7
# 32       9                         35                           5.3
# 33       9                         35                           5.3
# 34       9                         35                           5.3
# 35       9                         35                           5.3
# 36      10                         27                           4.1
# 37      10                         27                           4.1
# 38      10                         27                           4.1
# 39      10                         27                           4.1
# 40      11                         22                           3.3
# 41      11                         22                           3.3
# 42      12                         22                           3.3
# 43      12                         22                           3.3
# 44      12                         22                           3.3
# 45      12                         22                           3.3
# 46      12                         22                           3.3
# 47      13                         17                           2.6
# 48      13                         17                           2.6
# 49      13                         17                           2.6
# 50      13                         17                           2.6
#
#                            principales_palabras_clave
# 0   maximum power point tracking, fuzzy-logic base...
# 1   photo-voltaic  system,  differential   evoluti...
# 2   algorithm, double-fed induction generator (dfi...
# 3   photo voltaic array, firefly algorithm, partia...
# 4   support vector machine,  long  short-term  mem...
# 5   network,  convolution  neural  network,  speed...
# 6   consumption,   wind   power   forecasting,   e...
# 7   recurrent-neural-network (rnn), radial basis f...
# 8                                               farm.
# 9   smart grid, wind power, reinforcement learning...
# 10  efficiency, solar energy, deep reinforcement l...
# 11  internet of things, energy harvester, q-learning.
# 12  wind   turbine,   fault    diagnosis,    biodi...
# 13  response-surface methodology, condition monito...
# 14  consumption forecast,  anomalies  detection,  ...
# 15          supervisory control and data acquisition.
# 16  electric vehicle, lithium-ion batteries, state...
# 17  hybrid-electric vehicle, energy  management  s...
# 18  system, remaining useful life, battery managem...
# 19                             hybrid energy storage.
# 20  particle  swarm  optimization,  distribute  ge...
# 21  artificial  bee   colonies,   energy   storage...
# 22  gravitational search algorithm, distributed  s...
# 23  optimization  (mopso),  optimal  power-flow  (...
# 24  multi-objective   optimization,   energy   sto...
# 25  non-dominated  sorting  genetic  algorithm,   ...
# 26  renewable energy source, plug-in electric vehi...
# 27  multi-objective genetic algorithm, unit-commit...
# 28  genetic algorithm, demand-side  management,  e...
# 29  system (hes), wind turbine blade, data-driven ...
# 30  solar forecasting, geographic information syst...
# 31                                      cogeneration.
# 32  anfis,   global   solar   irradiance,  solar  ...
# 33  programing,   islanding   detection,   expert ...
# 34  evolutionary computation,  wavelet-based  neur...
# 35                       errors, virtual power plant.
# 36  micro grid,  multi-agent  systems,  distribute...
# 37  energy storage system, dc micro grid, pitch-co...
# 38  ac/dc microgrid, voltage regulation, supercond...
# 39                               distributed-control.
# 40  hydrogen,  biochar,  biomass,  biogas,  microb...
# 41  biofuel, ethanol, engine performance, pyrolysi...
# 42  state of charge (soc) estimation,  radial  bas...
# 43  forecasting,  computational  fluid  dynamics, ...
# 44  network,  monte-carlo   simulation,   multiple...
# 45  generation,   nonlinear   auto-regressive   ex...
# 46  networks, surrogate model, extreme gradient bo...
# 47  pem   fuel   cell,   solid-oxide  fuel  cell, ...
# 48  optimisation, particles-size  distributions,  ...
# 49  battery    management,    hydrogen     product...
# 50                             system-identification.

# %%
def join_words(words):
    return ' '.join(word.strip() for word in words if pd.notna(word))

#  antes de unir las palabras, elimina los espacios en blanco alrededor de cada palabra y filtra las palabras que no son NaN

# %%
# Agrupar y juntar palabras clave
clusters_report_df = (
    cluster_df.groupby(
        ["cluster", "cantidad_de_palabras_clave", "porcentaje_de_palabras_clave"],
        dropna=False,
    )["principales_palabras_clave"]
    .agg(join_words)
    .reset_index()
)

clusters_report_df
# Out:
#    cluster cantidad_de_palabras_clave  porcentaje_de_palabras_clave  \
# 0        1                        105                          15.9
# 1       10                         27                           4.1
# 2       11                         22                           3.3
# 3       12                         22                           3.3
# 4       13                         17                           2.6
# 5        2                        102                          15.4
# 6        3                         89                          13.4
# 7        4                         60                           9.1
# 8        5                         52                           7.9
# 9        6                         51                           7.7
# 10       7                         42                           6.3
# 11       8                         38                           5.7
# 12       9                         35                           5.3
#
#                            principales_palabras_clave
# 0   maximum power point tracking, fuzzy-logic base...
# 1   micro grid,  multi-agent  systems,  distribute...
# 2   hydrogen,  biochar,  biomass,  biogas,  microb...
# 3   state of charge (soc) estimation,  radial  bas...
# 4   pem   fuel   cell,   solid-oxide  fuel  cell, ...
# 5   support vector machine,  long  short-term  mem...
# 6   smart grid, wind power, reinforcement learning...
# 7   wind   turbine,   fault    diagnosis,    biodi...
# 8   electric vehicle, lithium-ion batteries, state...
# 9   particle  swarm  optimization,  distribute  ge...
# 10  multi-objective   optimization,   energy   sto...
# 11  genetic algorithm, demand-side  management,  e...
# 12  anfis,   global   solar   irradiance,  solar  ...

# %%
clusters_report_df["cluster"] = clusters_report_df["cluster"].astype(int)
clusters_report_df = clusters_report_df.sort_values(by="cluster")
clusters_report_df["principales_palabras_clave"] = (
    clusters_report_df["principales_palabras_clave"]
    .astype(str)
    .str.replace(",, ", ", ")
    .str.replace("   ", " ")
    .str.replace("  ", " ")
    .str.replace("hydrogen  production,  numeric", "hydrogen production, numeric")
    .str.replace(",  ", ", ")
    .str.replace(".", "")
    .str.lower()
)

clusters_report_df
# Out:
#     cluster cantidad_de_palabras_clave  porcentaje_de_palabras_clave  \
# 0         1                        105                          15.9
# 5         2                        102                          15.4
# 6         3                         89                          13.4
# 7         4                         60                           9.1
# 8         5                         52                           7.9
# 9         6                         51                           7.7
# 10        7                         42                           6.3
# 11        8                         38                           5.7
# 12        9                         35                           5.3
# 1        10                         27                           4.1
# 2        11                         22                           3.3
# 3        12                         22                           3.3
# 4        13                         17                           2.6
#
#                            principales_palabras_clave
# 0   maximum power point tracking, fuzzy-logic base...
# 5   support vector machine, long short-term memory...
# 6   smart grid, wind power, reinforcement learning...
# 7   wind turbine, fault diagnosis, biodiesel, fail...
# 8   electric vehicle, lithium-ion batteries, state...
# 9   particle swarm optimization, distribute genera...
# 10  multi-objective optimization, energy storage, ...
# 11  genetic algorithm, demand-side management, ene...
# 12  anfis, global solar irradiance, solar irradian...
# 1   micro grid, multi-agent systems, distributed e...
# 2   hydrogen, biochar, biomass, biogas, microbial ...
# 3   state of charge (soc) estimation, radial basis...
# 4   pem fuel cell, solid-oxide fuel cell, deep-bel...

# %%
clusters_report_df['principales_palabras_clave'] = clusters_report_df['principales_palabras_clave'].apply(lambda x: re.sub(r'([a-zA-Z]),([a-zA-Z])', r'\1, \2', x))
clusters_report_df["cantidad_de_palabras_clave"] = clusters_report_df[
    "cantidad_de_palabras_clave"
].astype(int)

clusters_report_df
# Out:
#     cluster  cantidad_de_palabras_clave  porcentaje_de_palabras_clave  \
# 0         1                         105                          15.9
# 5         2                         102                          15.4
# 6         3                          89                          13.4
# 7         4                          60                           9.1
# 8         5                          52                           7.9
# 9         6                          51                           7.7
# 10        7                          42                           6.3
# 11        8                          38                           5.7
# 12        9                          35                           5.3
# 1        10                          27                           4.1
# 2        11                          22                           3.3
# 3        12                          22                           3.3
# 4        13                          17                           2.6
#
#                            principales_palabras_clave
# 0   maximum power point tracking, fuzzy-logic base...
# 5   support vector machine, long short-term memory...
# 6   smart grid, wind power, reinforcement learning...
# 7   wind turbine, fault diagnosis, biodiesel, fail...
# 8   electric vehicle, lithium-ion batteries, state...
# 9   particle swarm optimization, distribute genera...
# 10  multi-objective optimization, energy storage, ...
# 11  genetic algorithm, demand-side management, ene...
# 12  anfis, global solar irradiance, solar irradian...
# 1   micro grid, multi-agent systems, distributed e...
# 2   hydrogen, biochar, biomass, biogas, microbial ...
# 3   state of charge (soc) estimation, radial basis...
# 4   pem fuel cell, solid-oxide fuel cell, deep-bel...
